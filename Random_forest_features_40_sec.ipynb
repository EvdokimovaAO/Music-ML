# %%
import pandas as pd
import audioread
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.metrics import recall_score, precision_score, classification_report

# %matplotlib inline

# %%
# считываем данные 
music = pd.read_csv("Desktop/BI/BI_2020-2021_Python/Music_classification/out_40_corrected.csv", encoding ='mac_cyrillic', sep=";")
music
# Out:
#                   student                                            song  \
# 0    Евдокимова_Анастасия                               Passacalia-Hendel
# 1           Журбенко Петр          Johannes_Passion—Johann_Sebastian_Bach
# 2         Иванова Евгения  Канон_Для_Струнного_Оркестра-Иоганн_Пахельбель
# 3        Людмила_Проценко                       A_Simple_Life-Brian_Crain
# 4         Никанорова Даша                      Adagio_in_G_Minor-Albinoni
# ..                    ...                                             ...
# 319          Шемякина Аня                 The_Struts_-_Primadonna_Like_Me
# 320        Aleksei Zverev                      Попрыгун_и_Гвозди-На_Убере
# 321        Aleksei Zverev                         Попрыгун_и_Гвозди-Рыбки
# 322        Aleksei Zverev                      Попрыгун_и_Гвозди-Черёмуха
# 323        Aleksei Zverev                        Электрослабость-Терентий
#
#     coarse_genre            genre1           genre2 genre3  \
# 0        classic      instrumental              NaN    NaN
# 1        classic              aria              NaN    NaN
# 2        classic               NaN              NaN    NaN
# 3        classic     neo-classical    new_age_piano    NaN
# 4        classic      instrumental              NaN    NaN
# ..           ...               ...              ...    ...
# 319         rock  alternative_rock        glam_rock    NaN
# 320         rock             indie  alternative_pop    NaN
# 321         rock             indie  alternative_pop    NaN
# 322         rock             indie  alternative_pop    NaN
# 323         rock              punk              NaN    NaN
#
#      zero_crossing_rate  spectral_centroid  spectral_rolloff       mfcc  ...  \
# 0              0.045798         748.314035       1269.271721 -11.941515  ...
# 1              0.076417        1414.632434       2666.842841 -10.983263  ...
# 2              0.085291        1490.988501       2839.114715  -5.051047  ...
# 3              0.042886         656.653479       1070.636358  -2.400885  ...
# 4              0.102339        1768.348182       3328.242111  -7.314991  ...
# ..                  ...                ...               ...        ...  ...
# 319            0.153660        3041.577527       6378.389715   9.809298  ...
# 320            0.086736        2103.759219       4411.500950   3.254812  ...
# 321            0.084793        2049.282500       4381.956846   3.578090  ...
# 322            0.071818        2010.463465       4376.270481   5.899025  ...
# 323            0.105174        2237.784308       4655.027356   3.145383  ...
#
#      chroma_frequencies_3  chroma_frequencies_4  chroma_frequencies_5  \
# 0                0.150021              0.153033              0.167364
# 1                0.319919              0.327633              0.360628
# 2                0.216023              0.297068              0.252765
# 3                0.347152              0.267500              0.206898
# 4                0.392298              0.412282              0.485981
# ..                    ...                   ...                   ...
# 319              0.503473              0.499696              0.385848
# 320              0.321782              0.289839              0.286502
# 321              0.460827              0.466181              0.423808
# 322              0.355812              0.447199              0.318935
# 323              0.173831              0.201809              0.180990
#
#      chroma_frequencies_6  chroma_frequencies_7  chroma_frequencies_8  \
# 0                0.191547              0.205490              0.187953
# 1                0.388893              0.381388              0.385996
# 2                0.303570              0.315133              0.249486
# 3                0.222848              0.253309              0.282360
# 4                0.478761              0.525003              0.381633
# ..                    ...                   ...                   ...
# 319              0.354051              0.368450              0.351270
# 320              0.307791              0.315518              0.292220
# 321              0.267113              0.187591              0.210219
# 322              0.252392              0.371693              0.407885
# 323              0.259762              0.233305              0.185266
#
#      chroma_frequencies_9  chroma_frequencies_10  chroma_frequencies_11  \
# 0                0.168512               0.154818               0.146623
# 1                0.293817               0.420031               0.248379
# 2                0.221325               0.201776               0.195795
# 3                0.310962               0.263674               0.224395
# 4                0.471162               0.381619               0.338369
# ..                    ...                    ...                    ...
# 319              0.441679               0.446410               0.542506
# 320              0.267222               0.281542               0.275587
# 321              0.308529               0.347520               0.287365
# 322              0.296010               0.305457               0.496221
# 323              0.175680               0.195392               0.220716
#
#      chroma_frequencies_12
# 0                 0.138912
# 1                 0.282112
# 2                 0.202072
# 3                 0.235438
# 4                 0.341242
# ..                     ...
# 319               0.320269
# 320               0.270769
# 321               0.459892
# 322               0.452474
# 323               0.227514
#
# [324 rows x 25 columns]

# %%
# Убираем фичи с NaN (random forest не умеет с ними работать)
music_clean = music.drop(["genre1","genre2", "genre3"], axis=1)
music_clean["coarse_genre"].value_counts()
# Out:
# electronic      79
# rock            75
# metal           53
# pop             42
# indie           27
# hip-hop         26
# instrumental     9
# classic          8
# jazz             5
# Name: coarse_genre, dtype: int64

# %%
# оставляем только наиболее многочисленные группы
music_clean_2 = music_clean.loc[music['coarse_genre'].isin(["rock","metal", "electronic", "pop", "indie", "hip-hop"])]

# %%
# разделяем фичи и предсказываемую переменную и оцениваем корреляцию переменных
X = music_clean_2.drop(["student", "song", "coarse_genre"], axis=1)
y = music_clean_2.loc[:,"coarse_genre"]
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col0,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col1,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col2,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row3_col3,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row4_col4,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row5_col5,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col6,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row7_col7,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row8_col8,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row9_col9,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row10_col10,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row11_col11,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row12_col12,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row13_col13,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row14_col14,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row15_col15,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row16_col16,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row17_col17,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row18_col18{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col1{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col2,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row15_col16{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col3,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col12{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col4,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col7,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row13_col5,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row16_col4{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col5{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col6{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col8,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row7_col5,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row15_col4{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col9,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row15_col5{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col10,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col5,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col11{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col11,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row17_col5{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col12,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col13{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col14,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col11{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col15,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row7_col6{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col16,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col17,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col5,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row10_col0,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row16_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row0_col18,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col8{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col0{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col2,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col1{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col3{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col4,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row5_col7{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col6{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col7{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col8,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col7{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col9,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col12,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row5_col0{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col10,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col10,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row9_col1{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col13,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col9,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col12,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col9{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col14{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col15,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row14_col6{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col16,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col16,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row11_col6{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col17,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row13_col1{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row1_col18,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col15,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row13_col6{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col0,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row8_col7{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col3,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row7_col16{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col4,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row5_col3{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col6,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col2{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col7,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row5_col4,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row6_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col8{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row2_col10,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row8_col6,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row13_col2,#T_3e64fe0a_a98b_11eb_90ea_244bfeba8b03row17_col1{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_3e64fe0a_a

# %%
# получаем выборки для обучения и тестирования
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# создаём классификатор
clf = RandomForestClassifier(criterion = "entropy")

# %%
# определяем параметры для настройки классификатора
parameters = {"n_estimators": range(1,100), 
              "min_samples_leaf": [4, 8, 12], 
             "max_depth": [3, 5, 7]}

# %%
# подстраиваем классификатор для максимальной точности
grid = GridSearchCV(clf, parameters, cv = 5)
grid.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e355f45f54e2> in <module>
#       1 # подстраиваем классификатор для максимальной точности
#       2 grid = GridSearchCV(clf, parameters, cv = 5)
# ----> 3 grid.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     190             y_encoded = np.zeros(y.shape, dtype=np.int)
#     191             for k in range(self.n_outputs_):
# --> 192                 classes_k, y_encoded[:, k] = np.unique(y[:, k],
#     193                                                        return_inverse=True)
#     194                 self.classes_.append(classes_k)
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     259     ar = np.asanyarray(ar)
#     260     if axis is None:
# --> 261         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     262         return _unpack_tuple(ret)
#     263
#
# ~\anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     317
#     318     if optional_indices:
# --> 319         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     320         aux = ar[perm]
#     321     else:
#
# KeyboardInterrupt:

# %%
# Оценка классификатора
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   electronic       0.62      0.72      0.67        25
#      hip-hop       0.00      0.00      0.00         9
#        indie       0.00      0.00      0.00         7
#        metal       0.68      0.87      0.76        15
#          pop       0.08      0.10      0.09        10
#         rock       0.44      0.48      0.46        25
#
#     accuracy                           0.48        91
#    macro avg       0.30      0.36      0.33        91
# weighted avg       0.41      0.48      0.45        91

# %%
# убираем автокоррелирующие фичи
X = music_clean_2.drop(["student", "song", "coarse_genre", "spectral_centroid", "spectral_rolloff", 
                       "chroma_frequencies_2", "chroma_frequencies_4", "chroma_frequencies_6", "chroma_frequencies_8",
                       "chroma_frequencies_10", "chroma_frequencies_12"], axis=1)
y = music_clean_2.loc[:,"coarse_genre"]
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col0,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col1,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col2,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col3,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col4,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col5,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row6_col6,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row7_col7,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row8_col8,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row9_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row10_col10{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col2,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col5,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row8_col3{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col3{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col4{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col6,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row9_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col7,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row10_col3{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col8{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col4{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row0_col10{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col0{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col2{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col3,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col0,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col1,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col4,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col5,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col7,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col8,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col10,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col6,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col4{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col5{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col6{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col7{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col8,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row8_col1{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col9{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row1_col10{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row2_col6{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col0{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col2,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col3{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col4{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col5{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col7,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row8_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col8{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row6_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row3_col10{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col0{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col1{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col5{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col6{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col7{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col8,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col10{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row4_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row8_col4{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col1{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col2{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col3,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row9_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col6,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row10_col9{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col7{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col8{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col9,#T_f30a017d_a990_11eb_a90c_244bfeba8b03row7_col1{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row5_col10{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row6_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c_244bfeba8b03row6_col1{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_f30a017d_a990_11eb_a90c

# %%
# повторное формирование выборок
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# повторное обучение классификатора 
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-23-6299373762b5> in <module>
#       1 grid = GridSearchCV(clf, parameters, cv = 5)
# ----> 2 y_pred = grid.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     484
#     485         """
# --> 486         self._check_is_fitted('predict')
#     487         return self.best_estimator_.predict(X)
#     488
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _check_is_fitted(self, method_name)
#     468                                  % (type(self).__name__, method_name))
#     469         else:
# --> 470             check_is_fitted(self)
#     471
#     472     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This GridSearchCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# оценка качества предсказаний
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   electronic       0.72      0.72      0.72        25
#      hip-hop       0.50      0.11      0.18         9
#        indie       0.33      0.14      0.20         7
#        metal       0.58      0.73      0.65        15
#          pop       0.17      0.20      0.18        10
#         rock       0.40      0.48      0.44        25
#
#     accuracy                           0.49        91
#    macro avg       0.45      0.40      0.39        91
# weighted avg       0.50      0.49      0.48        91
